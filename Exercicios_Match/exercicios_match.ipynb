# %% [markdown]
# 1. Tipo de dia
#
# Cria um programa que receba o nome de um dia da semana e diga se é dia útil ou fim de semana.
#
# Exemplo:
# Entrada → domingo
# Saída → Fim de semana

# %%
DiaSemana = input('Digite um dia da Semana: ')

match DiaSemana:
    case "sabado" | "domingo":
        print("Fim de Semana")

    case _:
        print("Dia útil")

# %% [markdown]
# 2. Classificação de nota
#
# Lê uma nota (0–100) e retorna uma classificação:
#
# 90 ou mais → Excelente
#
# 70–89 → Bom
#
# 50–69 → Suficiente
#
# Abaixo de 50 → Insuficiente
#
# Exemplo:
# Entrada → Bom
# Saída →  70-89

# %%
nota = int(input("Digite uma nota: "))

match nota:
    case _ if nota < 50:
        print("Insuficiente")

    case _ if 50 <= nota <= 69:
        print("Suficiente")

    case _ if 70 <= nota <= 89:
        print("Bom")

    case _ if nota >= 90:
        print("Excelente")

# %% [markdown]
# 3. Tipo de pedido
#
# Recebe um dicionário com as chaves "tipo" e "valor".
# Exibe:
#
# “Compra de X€” se tipo for “compra”
#
# “Venda de X€” se tipo for “venda”
#
# “Pedido desconhecido” caso contrário
#
# Exemplo:
# Entrada → {"tipo": "venda", "valor": 250}
# Saída → Venda de 250€

# %%
pedido = {"tipo": "venda", "valor": 250}

match pedido["tipo"]:
    case "venda":
        print("Venda de", pedido["valor"], "€")

    case "compra":
        print("Compra de", pedido["valor"], "€")

    case _:
        print("Pedido desconhecido")

# %% [markdown]
# 4. Tipo de dado
#
# Analisa um valor e retorna o seu tipo:
#
# Número inteiro
#
# Número decimal
#
# String numérica
#
# String textual
#
# Lista
#
# Tipo desconhecido
#
# Exemplo:
# Entrada → [10, 20, 30]
# Saída → Lista

# %%
valor = eval(input("Digite um valor: "))

match valor:
    case _ if isinstance(valor, int):
        print("Número inteiro")

    case _ if isinstance(valor, float):
        print("Número decimal")

    case _ if isinstance(valor, list):
        print("Lista")

    case _ if isinstance(valor, str) and valor.isnumeric():
        print("String numérica")

    case _ if isinstance(valor, str):
        print("String textual")

    case _:
        print("Tipo desconhecido")
# Out:
# Número inteiro

# %% [markdown]
# 5. Análise de mensagem
#
# Recebe uma mensagem e retorna:
#
# “Saudação” se for “olá” ou “bom dia”
#
# “Pergunta” se terminar com “?”
#
# “Despedida” se contiver “tchau” ou “adeus”
#
# “Mensagem genérica” caso contrário
#
# Exemplo:
# Entrada → “Tudo bem?”
# Saída → Pergunta

# %%
mensagem = input("Digite a sua mensagem: ").lower()

match mensagem:
    case _ if mensagem == "olá" or mensagem == "bom dia":
        print("Saudação")

    case _ if mensagem.endswith("?"):
        print("Pergunta")

    case _ if "tchau" in mensagem or "adeus" in mensagem:
        print("Despedida")

    case _:
        print("Mensagem genérica")

# %% [markdown]
# 6. Estado do servidor
#
# Recebe um dicionário com as chaves "status" e "tempo_resposta".
# Retorna:
#
# “Servidor ativo” se o status for “ok”
#
# “Servidor lento” se o status for “ok” e o tempo de resposta for maior que 200 ms
#
# “Servidor indisponível” se o status for “erro”
#
# “Estado desconhecido” caso contrário
#
# Exemplo:
# Entrada → {"status": "ok", "tempo_resposta": 350}
# Saída → Servidor lento

# %%
status = input("Status do servidor (ok/erro): ").lower()
tempo = int(input("Tempo de resposta (ms): "))

match True:

    case _ if status == "ok" and tempo > 200:
        print("Servidor lento")

    case _ if status == "ok":
        print("Servidor ativo")

    case _ if status == "erro":
        print("Servidor indisponível")

    case _:
        print("Estado desconhecido")

# %% [markdown]
# 7. Classificação de produto
#
# Recebe um dicionário com as chaves "categoria" e "preco".
# Retorna:
#
# “Produto de luxo” se categoria for “eletrônico” e preço acima de 1000
#
# “Produto comum” se categoria for “eletrônico” e preço até 1000
#
# “Produto alimentar” se categoria for “alimento”
#
# “Categoria desconhecida” caso contrário
#
# Exemplo:
# Entrada → {"categoria": "eletrônico", "preco": 1500}
# Saída → Produto de luxo

# %%
categoria = input("Categoria do produto: ").lower()
preco = float(input("Preço do produto: "))

match True:

    case _ if categoria == "eletronico" and preco > 1000:
        print("Produto de luxo")

    case _ if categoria == "eletronico":
        print("Produto comum")

    case _ if categoria == "alimento":
        print("Produto alimentar")

    case _:
        print("Categoria desconhecida")

# %% [markdown]
# 8. Operação matemática
#
# Recebe uma operação (em texto) e dois números.
# Operações válidas: "soma", "subtrai", "multiplica", "divide".
#
# Exemplo:
# Entrada →
# Operação: "divide"
# Número 1: 20
# Número 2: 4
# Saída → 5

# %%
n1 = int(input("Digite o 1º número: "))
n2 = int(input("Digite o 2º número: "))
op = input("Agora escolha uma das operações: 1 - Soma | 2 - Subtração | 3 - Multiplicação | 4 - Divisão: ")

match op:
    case "1":
        print(n1, "+", n2, "=", n1 + n2)

    case "2":
        print(n1, "-", n2, "=", n1 - n2)

    case "3":
        print(n1, "*", n2, "=", n1 * n2)

    case "4":
        if n2 == 0:
            print("Erro: divisão por zero não é permitida.")
        else:
            print(n1, "/", n2, "=", n1 / n2)

    case _:
        print("Operação inválida.")

# %% [markdown]
# 9. Processamento de requisição
#
# Recebe um dicionário com as chaves "metodo" e "conteudo".
# Retorna:
#
# “Requisição GET recebida” se o método for “GET”
#
# “Requisição POST com dados válidos” se o método for “POST” e o conteúdo não estiver vazio
#
# “Requisição POST sem dados” se o método for “POST” e o conteúdo estiver vazio
#
# “Método não suportado” caso contrário
#
# Exemplo:
# Entrada → {"metodo": "POST", "conteudo": ""}
# Saída → Requisição POST sem dados

# %%
metodo = input("Método (GET/POST): ").upper()
conteudo = input("Conteúdo: ")

match True:

    case _ if metodo == "POST" and conteudo == "":
        print("Requisição POST sem dados")

    case _ if metodo == "POST":
        print("Requisição POST com dados válidos")

    case _ if metodo == "GET":
        print("Requisição GET recebida")

    case _:
        print("Método não suportado")

# %% [markdown]
# 10. Jogo: Pedra, Papel ou Tesoura
#
# Cria um programa que receba duas jogadas:
#
# Jogador 1
#
# Jogador 2
#
# Usa match para determinar o resultado:
#
# Pedra ganha de Tesoura
#
# Tesoura ganha de Papel
#
# Papel ganha de Pedra
#
# Se forem iguais, é Empate
#
# Exemplo:
# Entrada →
# Jogador 1: pedra
# Jogador 2: tesoura
# Saída → Jogador 1 venceu

# %%
j1 = input("Jogador 1 - Escolha a sua jogada: 1 - Pedra | 2 - Papel | 3 - Tesoura")
j2 = input("Jogador 2 - Escolha a sua jogada: 1 - Pedra | 2 - Papel | 3 - Tesoura")

match (j1, j2):

    case ("1", "1") | ("2", "2") | ("3", "3"):
        print("Empate")

    case ("1", "3") | ("2", "1") | ("3", "2"):
        print("Jogador 1 venceu")

    case ("3", "1") | ("1", "2") | ("2", "3"):
        print("Jogador 2 venceu")

    case _:
        print("Operação inválida.")
